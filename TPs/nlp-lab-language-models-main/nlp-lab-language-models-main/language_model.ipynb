# %% [markdown]
# # NLP Lab : Modèles de langue
#
# Dans ce tp, nous allons constuire les briques principales du modèle GPT2 et entrainer un petit modèle sur des poèmes de Victor Hugo.
#
# Les questions sont posées dans ce notebook, puis pour executer l'entrainement, il faudra modifier le ficher `gpt_single_head.py` aussi disponible dans le reposository git.
#
#
# ## Données
#
# Les données d'entrainement sont un recueil de poèmes de Victor Hugo issu du site [gutenberg.org](https://www.gutenberg.org/). Elles sont disponibles dans le répertoire `data`.
#
# Afin de réduire la complexité du modèle, nous allons modéliser le texte au niveau caractère. Les modèles de language modélisent généralement des séquences de sous-mots en utilisant des [tokenizers](https://huggingface.co/docs/transformers/tokenizer_summary) (BPE, SentencePiece, WordPiece)
#
# Questions :
# >* En utilisant [collections.Counter](https://docs.python.org/3/library/collections.html#collections.Counter), afficher le nombre de caractères différents dans le texte et la fréquence de chaque caractère.

# %%
import collections

with open('data/hugo_contemplations.txt', 'r', encoding='utf-8') as f:
    text = f.read()

print(f'Number of characters in the file: {len(text)}')
##  YOUR CODE HERE
counter = collections.Counter(text)
chars = list(counter.keys())
vocab_size=len(chars)
###

print (f'Number of character in counter: {sum(counter.values())}')
print (f'{len(chars)} different characters')
print (counter)
# Out:
# Number of characters in the file: 285222
# Number of character in counter: 285222
# 101 different characters
# Counter({' ': 49127, 'e': 30253, 's': 17987, 'u': 14254, 'r': 14223, 't': 14071, 'a': 14048, 'n': 13725, 'i': 12828, 'o': 12653, 'l': 11638, '\n': 8102, 'm': 6495, 'd': 6375, ',': 6077, 'c': 5074, 'p': 4206, "'": 3820, 'v': 3492, 'é': 2943, 'b': 2783, 'f': 2772, 'h': 2221, 'q': 1956, 'g': 1790, '.': 1420, 'x': 1154, 'L': 1147, '!': 1121, 'E': 1074, ';': 1043, '-': 1020, 'j': 890, 'D': 764, 'è': 725, 'à': 706, 'y': 660, 'I': 627, 'ê': 605, 'C': 593, 'S': 545, 'A': 530, 'Q': 503, 'z': 482, 'J': 471, 'O': 450, 'T': 441, 'P': 435, '?': 388, 'V': 383, 'â': 381, 'N': 362, 'M': 344, 'ù': 298, ':': 294, 'R': 240, 'î': 214, 'U': 208, 'ô': 159, 'X': 150, '1': 146, 'H': 116, 'F': 114, '5': 111, '8': 93, 'B': 78, '«': 74, 'É': 70, '»': 69, 'G': 67, '4': 64, 'û': 62, '3': 47, 'ç': 34, 'À': 33, 'ë': 32, 'ï': 31, '2': 30, '·': 26, 'Ê': 24, '6': 23, '7': 23, 'Ô': 19, '9': 19, 'È': 11, 'k': 10, '0': 10, '_': 8, 'Z': 7, 'Æ': 4, '[': 4, ']': 4, 'w': 3, 'K': 3, 'Y': 3, 'Ë': 2, '(': 2, ')': 2, 'Â': 2, 'Î': 1, 'W': 1})

# %% [markdown]
# ### Encodage / décodage
# Afin de transformer le texte en vecteur pour le réseau de neurones, il faut encoder chaque caractère avec un entier. Les fonctions suivantes opérent l'encodage et le décodage des caractères :

# %%
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: transform a string into a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: transform a list of integers into a string


# test that your encoder/decoder is coherent
testString = "\nDemain, dès l'aube"
assert decode(encode (testString)) ==  testString

# %% [markdown]
# ### Découpage Train/Validation
#
# L'objectif étant de prédire des poèmes, il ne faut pas mélanger les lignes aléatoirement. Il faut garder l'ordre des lignes dans le texte et uniquement prendre les premiers 90% pour entrainer et les 10% restants pour contrôler l'apprentissage.
#
# Questions :
# > * Découper en `train_data` (90%) et `val_data` (10%) en utilisant du slicing sur data.

# %%
import torch
# Train and validation splits
data = torch.tensor(encode(text), dtype=torch.long)
## YOUR CODE HERE
# first 90% will be train, rest val
n = int(0.9 * len(data))
train_data = data[:n]
val_data = data[n:]
###

# %% [markdown]
# ### Contexte
#
# Le modèle de langue possède comme paramètre la taille maximale du contexte à considérer pour faire la prédiction du prochain caractère. Ce contexte est appelé `block_size`. Les données d'apprentissage sont donc des séquences de caractères consécutifs, issues de l'ensemble d'entraînenement tirées aléatoirement et de longueur `block_size`.
#
# Si le caractère de début de la séquence est `i`, la séquence de contexte est donc :
# ``` x = data[i:i+block_size]```
# et la valeur à prédire à chaque position dans le contexte est le caractère suivant :
# ```y = [data[i+1:i+block_size+1]```.

# %%
block_size = 8

i  = torch.randint(len(data) - block_size, (1,))
print (i)
x = train_data[i:i+block_size]
y = train_data[i+1:i+1+block_size]

for t in range(block_size):
    context = x[:t+1]
    target = y[t]
    print (f'context is >{decode(context.tolist())}< target is >{decode([target.tolist()])}<')
# Out:
# tensor([186452])
# context is >y< target is >a<
# context is >ya< target is >n<
# context is >yan< target is >t<
# context is >yant< target is > <
# context is >yant < target is >q<
# context is >yant q< target is >u<
# context is >yant qu< target is >e<
# context is >yant que< target is > <

# %% [markdown]
# ### Définition des batchs
#
# Les batchs d'entrainement sont constitués de plusieurs séquences de caractères tirées aléatoirement dans `train_data`. Pour choisir aléatoirement une séquence à mettre dans le batch, il faut tirer aléatoirement un point de départ dans `train_data` et extraire les `block_size` caractères suivants. Lors du tirage du point de départ, faire attention à laisser suffisamment de caractères après le point de départ pour avoir une séquence de `block_size` caractères.
#
# Questions :
# > * Créer les batchs `x` en tirant `batch_size` séquences de longeur `block_size` à  partir d'un point `i` tiré aléatoirement. Empiler les exemples avec `torch.stack`.
# > * Créer les batchs `y` en ajoutant le caractère suivant la séquence `x`. Empiler les exemples avec `torch.stack`.

# %%
batch_size = 4
torch.manual_seed(2023)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ## YOUR CODE HERE
    # select batch_size starting points in the data, store them in a list called starting_points
    starting_points = torch.randint(0, len(data) - block_size, (batch_size,))
    # x is the sequence of integer starting at each straing point and of length block_size
    x = torch.stack([data[i:i+block_size] for i in starting_points])
    # y is the character after each starting position
    y = torch.stack([data[i+1:i+block_size+1] for i in starting_points])
    ### 
    # send data and target to device
    x, y = x.to(device), y.to(device)
    return x, y

# %% [markdown]
# ### Premier modèle : un bigramme
#
# Le premier modèle que nous allons implémenter est un modèle bigramme. Il prédit le caractère suivant uniquement en fonction du caractère courant. Il est possible de stocker ce modèle dans une simple matrice : pour chaque caractère (en ligne), on stocke la distribution de probabilités sur l'ensemble des caractères suivants (en colonne). On peut donc le stocker dans une simple couche [`Embedding`](https://pytorch.org/docs/stable/generated/torch.nn.Embedding.html).
#
# Questions :
# > * Dans le constructeur, définir une couche Embedding de taille `vocab_size` par `vocab_size`.
# > * Dans forward, appliquer la couche d'embedding au batch de idx (`x`).
# > * Dans forward, définir la loss comme la `cross_entropy` entre la prédiction et target (`y`).

# %%
import torch.nn as nn

# use a gpu if we have one
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self, vocab_size):
        super().__init__()
        # we use a simple vocab_size times vocab_size tensor to store the probabilities 
        # of each token given a single token as context in nn.Embedding
        # YOUR CODE HERE
        self.token_embedding_table = nn.Embedding(vocab_size, vocab_size)
        ## 
        
    def forward(self, idx, targets=None):

        # idx and targets are both (Batch,Time) tensor of integers
        # YOUR CODE HERE
        logits = self.token_embedding_table(idx)  # (Batch, Time, vocab_size)
        ## 
   
        # don't compute loss if we don't have targets
        if targets is None:
            loss = None
        else:
            # change the shape of the logits and target to match what is needed for CrossEntropyLoss
            # https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html
            Batch, Time, Channels = logits.shape
            logits = logits.view(Batch*Time, Channels)
            targets = targets.view(Batch*Time)
            
            # negative log likelihood between prediction and target
            # YOUR CODE HERE
            loss = nn.functional.cross_entropy(logits, targets)
            ## 

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # get the predictions
            logits, loss = self(idx)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = nn.functional.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel(vocab_size)
# send the model to device
m = model.to(device)

# %% [markdown]
# #### Modèle avant entraînement
# Le modèle n'a pas encore été entrainé, il est juste initialisé, mais on peut calculer la loss sur un batch aléatoire. Les poids étant initialisés avec une distribution normale N(0,1) sur chaque dimension, la loss attendue après l'initialisation devrait être proche de `-ln(1/vocab_size)` (l'entropie est maximale).

# %%
import math
xb, yb = get_batch('train')
logits, loss = m(xb, yb)
print (logits.shape)
print (f'loss attendue {-math.log(1.0/vocab_size)}')
print (f'loss calculée {loss}')
# Out:
# torch.Size([32, 101])
# loss attendue 4.61512051684126
# loss calculée 5.095335960388184

# %% [markdown]
# Pour utiliser le modèle en prédiction, il faut lui fournir un premier caractère pour amorcer la séquence : c'est le prompt. Dans notre cas, on peut initialiser la génération avec le caractère de retour à la ligne pour débuter une nouvelle phrase.
#
# Questions :
# > * Créer un prompt avec un tenseur de taille (1,1) contenant l'entier correspondant au caractère `\n`.
# > * Générer une séquence de caractères de taille 100 à partir de ce prompt avec les fonctions `m.generate` et `decode`.
# > * Comment est la phrase générée ?

# %%
print (encode(['\n']))
## YOUR CODE HERE

# 1. Créer un prompt avec un tenseur de taille (1,1) contenant l'entier correspondant au caractère '\n'
prompt = torch.tensor([[encode('\n')[0]]], dtype=torch.long).to(device)

# 2. Générer une séquence de 100 caractères à partir du prompt
generated_seq = m.generate(prompt, max_new_tokens=100)

# 3. Décoder la séquence générée en texte
generated_text = decode(generated_seq[0].tolist())

# Afficher la séquence générée
print(generated_text)
# Out:
# [3]
#
# E6DnL!k1ïËçhSÂIHÆ-êud?HMYI0ïÔùZ(oaj
# YlMGCSÉ03ÎgQgnXzoEPu ëôWoBYn2:RèV(OÈhÊZ(bzÈ[OZq:]22hYdal»?ûdoÂ_s

# %% [markdown]
# ### Entrainement
#
# Pour l'entrainement, nous utilisons un optimiseur [AdamW](https://pytorch.org/docs/stable/generated/torch.optim.AdamW.html) avec un learning rate de 1e-3. Une itération d'apprentissage consiste en
# - générer un batch
# - appliquer le réseau de neurones (forward) et calculer la loss (`model(xb, yb)`)
# - calculer le gradient (après avoir remis à zero le gradient cumulé) (`loss.backward()`)
# - mettre à jour les paramètres (`optimizer.step()`).

# %%
max_iters = 100
batch_size = 4
eval_interval = 10
learning_rate = 1e-3
eval_iters = 20

@torch.no_grad() # no gradient is computed here
def estimate_loss():
    """ Estimate the loss on eval_iters batch of train and val sets."""
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

# re-create the model
model = BigramLanguageModel(vocab_size)
m = model.to(device)

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = m(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
# Out:
# step 0: train loss 5.2854, val loss 5.0871
# step 10: train loss 5.2775, val loss 5.0454
# step 20: train loss 5.1853, val loss 5.2105
# step 30: train loss 5.1590, val loss 5.0677
# step 40: train loss 5.1612, val loss 5.0610
# step 50: train loss 5.1555, val loss 5.0348
# step 60: train loss 5.1475, val loss 4.9888
# step 70: train loss 5.1956, val loss 5.0474
# step 80: train loss 5.1427, val loss 5.0917
# step 90: train loss 5.1557, val loss 5.0738

# %% [markdown]
# Une fois le réseau entrainé pendant 100 itérations, on peut générer une séquence de caractères.
#
# Questions :
# > * Quel est l'effet de l'entraînement ?
# > * Augmenter le nombre d'itérations à 1000 puis à 10,000, noter la loss obtenue et la phrase générée. Qu'observez-vous ?

# %%
idx = torch.ones((1,1), dtype=torch.long, device=device)*3
print (decode(m.generate(idx, max_new_tokens=100)[0].tolist()))
# Out:
# É6ejFtV2?[M_qJeBm]û PÊÂ5ÂZs9ÆùN;sXbAxSnÉ0Eç-8WHZYèVç'MPKT?XÆC1q,LH54êJN«X3AuaéB6
# Vguj.mYf1'xOEgà(êNo

# %%
max_iters = 1000
batch_size = 4
eval_interval = 10
learning_rate = 1e-3
eval_iters = 20

@torch.no_grad() # no gradient is computed here
def estimate_loss():
    """ Estimate the loss on eval_iters batch of train and val sets."""
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

# re-create the model
model = BigramLanguageModel(vocab_size)
m = model.to(device)

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = m(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
# Out:
# step 0: train loss 5.2121, val loss 5.2767
# step 10: train loss 5.0783, val loss 5.0855
# step 20: train loss 5.2422, val loss 5.3031
# step 30: train loss 5.0880, val loss 5.2114
# step 40: train loss 5.1639, val loss 5.2205
# step 50: train loss 5.0711, val loss 5.2071
# step 60: train loss 5.1343, val loss 5.2737
# step 70: train loss 5.0569, val loss 5.1176
# step 80: train loss 5.0166, val loss 5.1002
# step 90: train loss 5.0729, val loss 5.2166
# step 100: train loss 5.0785, val loss 5.1865
# step 110: train loss 5.0757, val loss 5.1522
# step 120: train loss 5.0974, val loss 5.1078
# step 130: train loss 5.0682, val loss 5.0868
# step 140: train loss 5.0013, val loss 5.1208
# step 150: train loss 5.0462, val loss 5.1104
# step 160: train loss 4.9295, val loss 5.0547
# step 170: train loss 5.0009, val loss 5.1255
# step 180: train loss 5.0478, val loss 4.9877
# step 190: train loss 4.9585, val loss 5.0235
# step 200: train loss 5.0373, val loss 5.1005
# step 210: train loss 4.9690, val loss 5.0939
# step 220: train loss 4.9016, val loss 5.0330
# step 230: train loss 4.9154, val loss 5.0275
# step 240: train loss 4.9234, val loss 5.0847
# step 250: train loss 4.9263, val loss 4.9782
# step 260: train loss 4.8779, val loss 5.0781
# step 270: train loss 4.8936, val loss 4.9201
# step 280: train loss 4.9375, val loss 5.0048
# step 290: train loss 4.9491, val loss 4.9899
# step 300: train loss 4.9507, val loss 4.9604
# step 310: train loss 4.9063, val loss 5.0087
# step 320: train loss 4.8663, val loss 4.9996
# step 330: train loss 4.8863, val loss 4.9619
# step 340: train loss 4.8503, val loss 5.0948
# step 350: train loss 4.7936, val loss 4.8862
# step 360: train loss 4.8577, val loss 4.9262
# step 370: train loss 4.7972, val loss 4.8560
# step 380: train loss 4.8190, val loss 4.8377
# step 390: train loss 4.7753, val loss 4.8564
# step 400: train loss 4.8260, val loss 4.8757
# step 410: train loss 4.8409, val loss 4.9298
# step 420: train loss 4.8130, val loss 4.9312
# step 430: train loss 4.7935, val loss 4.9699
# step 440: train loss 4.7723, val loss 4.8647
# step 450: train loss 4.7328, val loss 4.9519
# step 460: train loss 4.7274, val loss 4.8340
# step 470: train loss 4.7949, val loss 4.8875
# step 480: train loss 4.7708, val loss 4.8309
# step 490: train loss 4.7194, val loss 4.8924
# step 500: train loss 4.7187, val loss 4.8123
# step 510: train loss 4.7378, val loss 4.8142
# step 520: train loss 4.6553, val loss 4.8397
# step 530: train loss 4.7077, val loss 4.8174
# step 540: train loss 4.6726, val loss 4.8271
# step 550: train loss 4.6694, val loss 4.8925
# step 560: train loss 4.6592, val loss 4.8452
# step 570: train loss 4.6270, val loss 4.7364
# step 580: train loss 4.6698, val loss 4.7358
# step 590: train loss 4.6711, val loss 4.8305
# step 600: train loss 4.7103, val loss 4.6330
# step 610: train loss 4.6359, val loss 4.7620
# step 620: train loss 4.6446, val loss 4.7145
# step 630: train loss 4.5604, val loss 4.7099
# step 640: train loss 4.5331, val loss 4.6534
# step 650: train loss 4.5613, val loss 4.7600
# step 660: train loss 4.5980, val loss 4.7295
# step 670: train loss 4.6583, val loss 4.6945
# step 680: train loss 4.5156, val loss 4.5985
# step 690: train loss 4.5763, val loss 4.6826
# step 700: train loss 4.5488, val loss 4.7436
# step 710: train loss 4.5311, val loss 4.7730
# step 720: train loss 4.5772, val loss 4.7268
# step 730: train loss 4.5753, val loss 4.6059
# step 740: train loss 4.5231, val loss 4.6690
# step 750: train loss 4.5572, val loss 4.6616
# step 760: train loss 4.5515, val loss 4.5743
# step 770: train loss 4.4847, val loss 4.6371
# step 780: train loss 4.4881, val loss 4.5662
# step 790: train loss 4.5187, val loss 4.5287
# step 800: train loss 4.4808, val loss 4.6134
# step 810: train loss 4.5289, val loss 4.5548
# step 820: train loss 4.5062, val loss 4.6664
# step 830: train loss 4.4059, val loss 4.5890
# step 840: train loss 4.4383, val loss 4.5539
# step 850: train loss 4.4603, val loss 4.5784
# step 860: train loss 4.4908, val loss 4.5113
# step 870: train loss 4.4716, val loss 4.5510
# step 880: train loss 4.3994, val loss 4.5588
# step 890: train loss 4.4040, val loss 4.5022
# step 900: train loss 4.3759, val loss 4.5425
# step 910: train loss 4.3063, val loss 4.5411
# step 920: train loss 4.4320, val loss 4.5382
# step 930: train loss 4.3858, val loss 4.5055
# step 940: train loss 4.4142, val loss 4.4717
# step 950: train loss 4.3547, val loss 4.4861
# step 960: train loss 4.3493, val loss 4.4770
# step 970: train loss 4.3376, val loss 4.5338
# step 980: train loss 4.3523, val loss 4.5520
# step 990: train loss 4.4396, val loss 4.4942

# %%
idx = torch.ones((1,1), dtype=torch.long, device=device)*3
print (decode(m.generate(idx, max_new_tokens=100)[0].tolist()))
# Out:
# wb,PÈcSgV)IMysmuPPÔfZu,uXE[éÊkWû àxïèÉZàHa Sj(_BGTd-]çjz[âêêqw»MLbk6BWTTïl)XNd5àqqUhLs]VîGÉËfr[ÎcÀuE

# %%
max_iters = 10000
batch_size = 4
eval_interval = 10
learning_rate = 1e-3
eval_iters = 20

@torch.no_grad() # no gradient is computed here
def estimate_loss():
    """ Estimate the loss on eval_iters batch of train and val sets."""
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

# re-create the model
model = BigramLanguageModel(vocab_size)
m = model.to(device)

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = m(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
# Out:
# step 0: train loss 4.9758, val loss 4.9016
# step 10: train loss 5.0034, val loss 4.8438
# step 20: train loss 4.9716, val loss 4.9427
# step 30: train loss 5.0279, val loss 4.7915
# step 40: train loss 4.9312, val loss 4.8421
# step 50: train loss 4.9638, val loss 4.8159
# step 60: train loss 4.9519, val loss 4.8556
# step 70: train loss 4.8973, val loss 4.7887
# step 80: train loss 4.9455, val loss 4.7840
# step 90: train loss 4.9222, val loss 4.8033
# step 100: train loss 4.8818, val loss 4.8655
# step 110: train loss 4.9012, val loss 4.8760
# step 120: train loss 4.8517, val loss 4.8221
# step 130: train loss 4.8513, val loss 4.7741
# step 140: train loss 4.8675, val loss 4.7923
# step 150: train loss 4.9491, val loss 4.8648
# step 160: train loss 4.9213, val loss 4.7807
# step 170: train loss 4.8519, val loss 4.7767
# step 180: train loss 4.8935, val loss 4.7161
# step 190: train loss 4.8298, val loss 4.7409
# step 200: train loss 4.8529, val loss 4.7972
# step 210: train loss 4.8042, val loss 4.7036
# step 220: train loss 4.8510, val loss 4.6803
# step 230: train loss 4.8801, val loss 4.6533
# step 240: train loss 4.8254, val loss 4.7199
# step 250: train loss 4.8877, val loss 4.7232
# step 260: train loss 4.7421, val loss 4.7084
# step 270: train loss 4.7243, val loss 4.6830
# step 280: train loss 4.8305, val loss 4.5962
# step 290: train loss 4.7965, val loss 4.6684
# step 300: train loss 4.8170, val loss 4.7148
# step 310: train loss 4.7144, val loss 4.5746
# step 320: train loss 4.6487, val loss 4.6442
# step 330: train loss 4.7499, val loss 4.7357
# step 340: train loss 4.7008, val loss 4.5739
# step 350: train loss 4.7001, val loss 4.6876
# step 360: train loss 4.6210, val loss 4.5466
# step 370: train loss 4.6507, val loss 4.6887
# step 380: train loss 4.6454, val loss 4.4703
# step 390: train loss 4.6652, val loss 4.5211
# step 400: train loss 4.6884, val loss 4.5093
# step 410: train loss 4.6086, val loss 4.4925
# step 420: train loss 4.6976, val loss 4.6060
# step 430: train loss 4.6469, val loss 4.6109
# step 440: train loss 4.6700, val loss 4.5514
# step 450: train loss 4.5911, val loss 4.6135
# step 460: train loss 4.6042, val loss 4.6041
# step 470: train loss 4.6372, val loss 4.5456
# step 480: train loss 4.6615, val loss 4.4292
# step 490: train loss 4.6325, val loss 4.5636
# step 500: train loss 4.5961, val loss 4.3926
# step 510: train loss 4.5803, val loss 4.4979
# step 520: train loss 4.5563, val loss 4.4514
# step 530: train loss 4.4984, val loss 4.4811
# step 540: train loss 4.5091, val loss 4.3912
# step 550: train loss 4.5655, val loss 4.4953
# step 560: train loss 4.4913, val loss 4.3583
# step 570: train loss 4.4775, val loss 4.4302
# step 580: train loss 4.4778, val loss 4.4133
# step 590: train loss 4.5962, val loss 4.4257
# step 600: train loss 4.4880, val loss 4.3771
# step 610: train loss 4.4749, val loss 4.4693
# step 620: train loss 4.5535, val loss 4.3635
# step 630: train loss 4.4211, val loss 4.3600
# step 640: train loss 4.4704, val loss 4.3667
# step 650: train loss 4.4809, val loss 4.3441
# step 660: train loss 4.4706, val loss 4.4412
# step 670: train loss 4.4621, val loss 4.3278
# step 680: train loss 4.4059, val loss 4.3251
# step 690: train loss 4.4678, val loss 4.2481
# step 700: train loss 4.4885, val loss 4.4349
# step 710: train loss 4.3504, val loss 4.3410
# step 720: train loss 4.4188, val loss 4.2937
# step 730: train loss 4.4875, val loss 4.2890
# step 740: train loss 4.3782, val loss 4.2936
# step 750: train loss 4.4275, val loss 4.2640
# step 760: train loss 4.3617, val loss 4.2616
# step 770: train loss 4.3764, val loss 4.2850
# step 780: train loss 4.3822, val loss 4.2916
# step 790: train loss 4.4296, val loss 4.3140
# step 800: train loss 4.4499, val loss 4.2829
# step 810: train loss 4.3255, val loss 4.2975
# step 820: train loss 4.3541, val loss 4.2068
# step 830: train loss 4.3385, val loss 4.2025
# step 840: train loss 4.3032, val loss 4.2635
# step 850: train loss 4.3826, val loss 4.3012
# step 860: train loss 4.2816, val loss 4.2633
# step 870: train loss 4.2629, val loss 4.2488
# step 880: train loss 4.2932, val loss 4.1927
# step 890: train loss 4.3287, val loss 4.2709
# step 900: train loss 4.2479, val loss 4.2458
# step 910: train loss 4.3040, val loss 4.1724
# step 920: train loss 4.2476, val loss 4.2946
# step 930: train loss 4.2675, val loss 4.1649
# step 940: train loss 4.2311, val loss 4.2192
# step 950: train loss 4.2450, val loss 4.1462
# step 960: train loss 4.2914, val loss 4.0922
# step 970: train loss 4.2105, val loss 4.1668
# step 980: train loss 4.1930, val loss 4.1357
# step 990: train loss 4.2126, val loss 4.1190
# step 1000: train loss 4.1868, val loss 4.2115
# step 1010: train loss 4.2122, val loss 4.0415
# step 1020: train loss 4.1692, val loss 4.1369
# step 1030: train loss 4.2171, val loss 4.1411
# step 1040: train loss 4.2058, val loss 4.1461
# step 1050: train loss 4.1237, val loss 4.1381
# step 1060: train loss 4.1385, val loss 4.0560
# step 1070: train loss 4.2204, val loss 4.0680
# step 1080: train loss 4.2618, val loss 4.0453
# step 1090: train loss 4.1725, val loss 4.0434
# step 1100: train loss 4.1642, val loss 4.0382
# step 1110: train loss 4.1395, val loss 4.1003
# step 1120: train loss 4.1324, val loss 4.0491
# step 1130: train loss 4.1086, val loss 4.1255
# step 1140: train loss 4.1625, val loss 3.9854
# step 1150: train loss 4.1448, val loss 4.0649
# step 1160: train loss 4.1586, val loss 3.9705
# step 1170: train loss 4.0901, val loss 4.0472
# step 1180: train loss 4.1973, val loss 4.0478
# step 1190: train loss 4.0791, val loss 3.9657
# step 1200: train loss 4.0458, val loss 4.0631
# step 1210: train loss 4.1578, val loss 4.0097
# step 1220: train loss 4.0595, val loss 3.9437
# step 1230: train loss 4.1032, val loss 3.9820
# step 1240: train loss 4.0615, val loss 3.9568
# step 1250: train loss 4.0587, val loss 4.0092
# step 1260: train loss 4.1168, val loss 3.9907
# step 1270: train loss 3.9954, val loss 3.9643
# step 1280: train loss 4.1062, val loss 3.8353
# step 1290: train loss 4.0009, val loss 3.8948
# step 1300: train loss 4.0253, val loss 3.9869
# step 1310: train loss 4.0648, val loss 3.9624
# step 1320: train loss 4.0715, val loss 3.8830
# step 1330: train loss 3.9695, val loss 3.9550
# step 1340: train loss 3.9851, val loss 3.9725
# step 1350: train loss 4.0010, val loss 3.9817
# step 1360: train loss 4.0250, val loss 3.9468
# step 1370: train loss 3.9392, val loss 3.9319
# step 1380: train loss 4.0018, val loss 3.8657
# step 1390: train loss 3.9604, val loss 4.0166
# step 1400: train loss 3.9616, val loss 3.9418
# step 1410: train loss 3.9013, val loss 3.9776
# step 1420: train loss 3.9414, val loss 3.9399
# step 1430: train loss 3.9507, val loss 3.8895
# step 1440: train loss 3.9182, val loss 3.8499
# step 1450: train loss 3.9221, val loss 3.9303
# step 1460: train loss 4.0015, val loss 3.8567
# step 1470: train loss 3.9596, val loss 3.9435
# step 1480: train loss 3.8887, val loss 3.8209
# step 1490: train loss 3.9413, val loss 3.8940
# step 1500: train loss 3.8956, val loss 3.7808
# step 1510: train loss 3.9453, val loss 3.8244
# step 1520: train loss 3.8936, val loss 3.9067
# step 1530: train loss 3.9968, val loss 3.8626
# step 1540: train loss 3.9033, val loss 3.8807
# step 1550: train loss 3.9038, val loss 3.7142
# step 1560: train loss 3.8461, val loss 3.8093
# step 1570: train loss 3.9079, val loss 3.8380
# step 1580: train loss 3.8318, val loss 3.7795
# step 1590: train loss 3.8227, val loss 3.7489
# step 1600: train loss 3.8741, val loss 3.8533
# step 1610: train loss 3.8334, val loss 3.7589
# step 1620: train loss 3.8349, val loss 3.7178
# step 1630: train loss 3.8584, val loss 3.7927
# step 1640: train loss 3.7874, val loss 3.7696
# step 1650: train loss 3.8083, val loss 3.7552
# step 1660: train loss 3.8047, val loss 3.7435
# step 1670: train loss 3.8099, val loss 3.7486
# step 1680: train loss 3.8289, val loss 3.7528
# step 1690: train loss 3.7597, val loss 3.8423
# step 1700: train loss 3.7706, val loss 3.8811
# step 1710: train loss 3.7373, val loss 3.7035
# step 1720: train loss 3.7560, val loss 3.7248
# step 1730: train loss 3.8109, val loss 3.7300
# step 1740: train loss 3.7406, val loss 3.7773
# step 1750: train loss 3.7363, val loss 3.7099
# step 1760: train loss 3.7302, val loss 3.6986
# step 1770: train loss 3.8061, val loss 3.7066
# step 1780: train loss 3.7179, val loss 3.6747
# step 1790: train loss 3.6817, val loss 3.7731
# step 1800: train loss 3.6963, val loss 3.6671
# step 1810: train loss 3.7273, val loss 3.7245
# step 1820: train loss 3.7681, val loss 3.7803
# step 1830: train loss 3.7569, val loss 3.7037
# step 1840: train loss 3.7826, val loss 3.7176
# step 1850: train loss 3.7518, val loss 3.8415
# step 1860: train loss 3.7877, val loss 3.6307
# step 1870: train loss 3.6928, val loss 3.7355
# step 1880: train loss 3.7105, val loss 3.6482
# step 1890: train loss 3.6726, val loss 3.6672
# step 1900: train loss 3.6422, val loss 3.5725
# step 1910: train loss 3.6210, val loss 3.7201
# step 1920: train loss 3.6591, val loss 3.5791
# step 1930: train loss 3.7038, val loss 3.5728
# step 1940: train loss 3.6848, val loss 3.5716
# step 1950: train loss 3.6501, val loss 3.6119
# step 1960: train loss 3.6751, val loss 3.6201
# step 1970: train loss 3.6562, val loss 3.6683
# step 1980: train loss 3.7298, val loss 3.6768
# step 1990: train loss 3.6415, val loss 3.6446
# step 2000: train loss 3.6261, val loss 3.6073
# step 2010: train loss 3.7153, val loss 3.6556
# step 2020: train loss 3.6398, val loss 3.5960
# step 2030: train loss 3.6351, val loss 3.5770
# step 2040: train loss 3.6274, val loss 3.6003
# step 2050: train loss 3.6699, val loss 3.5289
# step 2060: train loss 3.5701, val loss 3.6749
# step 2070: train loss 3.6346, val loss 3.5317
# step 2080: train loss 3.6551, val loss 3.5362
# step 2090: train loss 3.5372, val loss 3.5535
# step 2100: train loss 3.6417, val loss 3.5539
# step 2110: train loss 3.6217, val loss 3.5975
# step 2120: train loss 3.5987, val loss 3.5525
# step 2130: train loss 3.6086, val loss 3.4259
# step 2140: train loss 3.5682, val loss 3.4926
# step 2150: train loss 3.5752, val loss 3.4805
# step 2160: train loss 3.5618, val loss 3.4403
# step 2170: train loss 3.5581, val loss 3.5466
# step 2180: train loss 3.5297, val loss 3.5184
# step 2190: train loss 3.5359, val loss 3.5266
# step 2200: train loss 3.6010, val loss 3.4616
# step 2210: train loss 3.5654, val loss 3.4714
# step 2220: train loss 3.4963, val loss 3.5586
# step 2230: train loss 3.5368, val loss 3.4828
# step 2240: train loss 3.4691, val loss 3.5225
# step 2250: train loss 3.4569, val loss 3.5504
# step 2260: train loss 3.4880, val loss 3.4425
# step 2270: train loss 3.4887, val loss 3.5462
# step 2280: train loss 3.5010, val loss 3.4381
# step 2290: train loss 3.6141, val loss 3.4390
# step 2300: train loss 3.5337, val loss 3.4504
# step 2310: train loss 3.5147, val loss 3.4039
# step 2320: train loss 3.4951, val loss 3.5003
# step 2330: train loss 3.4380, val loss 3.4240
# step 2340: train loss 3.4607, val loss 3.4432
# step 2350: train loss 3.4834, val loss 3.4823
# step 2360: train loss 3.4218, val loss 3.4366
# step 2370: train loss 3.4283, val loss 3.3606
# step 2380: train loss 3.5564, val loss 3.4235
# step 2390: train loss 3.4890, val loss 3.4491
# step 2400: train loss 3.4939, val loss 3.4933
# step 2410: train loss 3.4370, val loss 3.4534
# step 2420: train loss 3.3985, val loss 3.3957
# step 2430: train loss 3.4546, val loss 3.4439
# step 2440: train loss 3.4056, val loss 3.4462
# step 2450: train loss 3.5721, val loss 3.3907
# step 2460: train loss 3.4009, val loss 3.5006
# step 2470: train loss 3.4478, val loss 3.4446
# step 2480: train loss 3.3684, val loss 3.3302
# step 2490: train loss 3.4789, val loss 3.4278
# step 2500: train loss 3.4051, val loss 3.4187
# step 2510: train loss 3.4481, val loss 3.5256
# step 2520: train loss 3.3773, val loss 3.4176
# step 2530: train loss 3.4298, val loss 3.3287
# step 2540: train loss 3.3245, val loss 3.3900
# step 2550: train loss 3.4662, val loss 3.3509
# step 2560: train loss 3.4265, val loss 3.2837
# step 2570: train loss 3.3608, val loss 3.3905
# step 2580: train loss 3.2882, val loss 3.4770
# step 2590: train loss 3.3106, val loss 3.3239
# step 2600: train loss 3.3564, val loss 3.3530
# step 2610: train loss 3.3253, val loss 3.3603
# step 2620: train loss 3.3870, val loss 3.2302
# step 2630: train loss 3.3254, val loss 3.4410
# step 2640: train loss 3.3733, val loss 3.3351
# step 2650: train loss 3.3517, val loss 3.3302
# step 2660: train loss 3.3948, val loss 3.3414
# step 2670: train loss 3.3303, val loss 3.2134
# step 2680: train loss 3.3527, val loss 3.3987
# step 2690: train loss 3.2694, val loss 3.3692
# step 2700: train loss 3.3468, val loss 3.3421
# step 2710: train loss 3.3585, val loss 3.3180
# step 2720: train loss 3.4134, val loss 3.3155
# step 2730: train loss 3.3156, val loss 3.3210
# step 2740: train loss 3.3119, val loss 3.4449
# step 2750: train loss 3.2550, val loss 3.4112
# step 2760: train loss 3.2982, val loss 3.3242
# step 2770: train loss 3.3443, val loss 3.3494
# step 2780: train loss 3.3734, val loss 3.4271
# step 2790: train loss 3.3200, val loss 3.1929
# step 2800: train loss 3.3236, val loss 3.2244
# step 2810: train loss 3.3029, val loss 3.3345
# step 2820: train loss 3.2805, val loss 3.2636
# step 2830: train loss 3.2203, val loss 3.3238
# step 2840: train loss 3.3087, val loss 3.4260
# step 2850: train loss 3.3705, val loss 3.2873
# step 2860: train loss 3.2583, val loss 3.2470
# step 2870: train loss 3.2464, val loss 3.2285
# step 2880: train loss 3.2949, val loss 3.1665
# step 2890: train loss 3.2587, val loss 3.2568
# step 2900: train loss 3.2923, val loss 3.3137
# step 2910: train loss 3.2618, val loss 3.2507
# step 2920: train loss 3.2974, val loss 3.3879
# step 2930: train loss 3.2253, val loss 3.2155
# step 2940: train loss 3.2869, val loss 3.2787
# step 2950: train loss 3.2518, val loss 3.3456
# step 2960: train loss 3.2664, val loss 3.2494
# step 2970: train loss 3.2639, val loss 3.2668
# step 2980: train loss 3.3015, val loss 3.2562
# step 2990: train loss 3.2401, val loss 3.2101
# step 3000: train loss 3.2427, val loss 3.2470
# step 3010: train loss 3.1932, val loss 3.1280
# step 3020: train loss 3.2715, val loss 3.2473
# step 3030: train loss 3.1886, val loss 3.2181
# step 3040: train loss 3.2249, val loss 3.1416
# step 3050: train loss 3.2347, val loss 3.2222
# step 3060: train loss 3.2175, val loss 3.2101
# step 3070: train loss 3.2910, val loss 3.2113
# step 3080: train loss 3.2166, val loss 3.1398
# step 3090: train loss 3.2756, val loss 3.2969
# step 3100: train loss 3.1141, val loss 3.3480
# step 3110: train loss 3.2331, val loss 3.2499
# step 3120: train loss 3.2363, val loss 3.2698
# step 3130: train loss 3.2284, val loss 3.1722
# step 3140: train loss 3.2661, val loss 3.2398
# step 3150: train loss 3.2068, val loss 3.2215
# step 3160: train loss 3.1758, val loss 3.2079
# step 3170: train loss 3.1456, val loss 3.0781
# step 3180: train loss 3.2329, val loss 3.1981
# step 3190: train loss 3.1434, val loss 3.1885
# step 3200: train loss 3.1861, val loss 3.1912
# step 3210: train loss 3.1493, val loss 3.2035
# step 3220: train loss 3.1683, val loss 3.3072
# step 3230: train loss 3.2547, val loss 3.2921
# step 3240: train loss 3.1559, val loss 3.1249
# step 3250: train loss 3.1782, val loss 3.1359
# step 3260: train loss 3.1038, val loss 3.1508
# step 3270: train loss 3.1371, val loss 3.2202
# step 3280: train loss 3.1542, val loss 3.2217
# step 3290: train loss 3.1288, val loss 3.1973
# step 3300: train loss 3.1349, val loss 3.1836
# step 3310: train loss 3.1462, val loss 3.1442
# step 3320: train loss 3.1424, val loss 3.1886
# step 3330: train loss 3.1114, val loss 3.1244
# step 3340: train loss 3.0745, val loss 3.2271
# step 3350: train loss 3.1498, val loss 3.1463
# step 3360: train loss 3.1054, val loss 3.2543
# step 3370: train loss 3.0816, val loss 3.0827
# step 3380: train loss 3.0517, val loss 3.1583
# step 3390: train loss 3.1851, val loss 3.1538
# step 3400: train loss 3.0874, val loss 3.2240
# step 3410: train loss 3.1741, val loss 3.0838
# step 3420: train loss 3.1190, val loss 3.0798
# step 3430: train loss 3.1200, val loss 3.1528
# step 3440: train loss 3.1555, val loss 3.1887
# step 3450: train loss 3.1040, val loss 3.1910
# step 3460: train loss 3.1291, val loss 3.0952
# step 3470: train loss 3.1646, val loss 3.1589
# step 3480: train loss 3.0950, val loss 3.0024
# step 3490: train loss 3.1586, val loss 3.1091
# step 3500: train loss 3.1404, val loss 3.2830
# step 3510: train loss 3.0557, val loss 3.2110
# step 3520: train loss 3.0601, val loss 3.0560
# step 3530: train loss 3.1541, val loss 3.0608
# step 3540: train loss 3.0797, val loss 3.0537
# step 3550: train loss 3.0424, val loss 3.2210
# step 3560: train loss 3.0462, val loss 3.1766
# step 3570: train loss 3.0885, val loss 3.0152
# step 3580: train loss 3.0698, val loss 3.0104
# step 3590: train loss 3.0248, val loss 3.0683
# step 3600: train loss 2.9913, val loss 3.1420
# step 3610: train loss 3.0192, val loss 3.0485
# step 3620: train loss 3.0734, val loss 3.0680
# step 3630: train loss 3.1017, val loss 3.0994
# step 3640: train loss 2.9539, val loss 2.9987
# step 3650: train loss 3.1355, val loss 3.0016
# step 3660: train loss 3.0788, val loss 3.1171
# step 3670: train loss 3.0293, val loss 2.9887
# step 3680: train loss 3.0661, val loss 3.0851
# step 3690: train loss 3.0708, val loss 3.0616
# step 3700: train loss 2.9981, val loss 3.1040
# step 3710: train loss 3.0421, val loss 2.9907
# step 3720: train loss 2.9817, val loss 3.0915
# step 3730: train loss 2.9987, val loss 3.0952
# step 3740: train loss 2.9645, val loss 3.1067
# step 3750: train loss 3.0185, val loss 3.0384
# step 3760: train loss 2.9188, val loss 3.1496
# step 3770: train loss 3.0426, val loss 3.1610
# step 3780: train loss 3.0528, val loss 2.9879
# step 3790: train loss 3.0264, val loss 3.0006
# step 3800: train loss 3.0030, val loss 3.0361
# step 3810: train loss 3.0471, val loss 3.1569
# step 3820: train loss 3.0165, val loss 3.0786
# step 3830: train loss 2.9827, val loss 3.0598
# step 3840: train loss 2.9963, val loss 2.9856
# step 3850: train loss 3.0759, val loss 3.0815
# step 3860: train loss 3.0213, val loss 3.0038
# step 3870: train loss 3.0270, val loss 3.0832
# step 3880: train loss 2.9296, val loss 3.0254
# step 3890: train loss 2.9892, val loss 2.9652
# step 3900: train loss 2.9029, val loss 3.0900
# step 3910: train loss 3.0766, val loss 3.1013
# step 3920: train loss 3.0523, val loss 2.9853
# step 3930: train loss 3.0037, val loss 3.1009
# step 3940: train loss 2.9750, val loss 3.0302
# step 3950: train loss 3.0067, val loss 3.0150
# step 3960: train loss 3.0406, val loss 2.8952
# step 3970: train loss 3.0866, val loss 2.9138
# step 3980: train loss 3.0475, val loss 3.0077
# step 3990: train loss 3.0413, val loss 2.9903
# step 4000: train loss 3.0472, val loss 2.9546
# step 4010: train loss 2.8774, val loss 3.0965
# step 4020: train loss 2.9406, val loss 3.0513
# step 4030: train loss 2.9712, val loss 2.9615
# step 4040: train loss 2.9712, val loss 2.9807
# step 4050: train loss 2.9149, val loss 3.0474
# step 4060: train loss 2.9932, val loss 2.8711
# step 4070: train loss 2.9855, val loss 3.0352
# step 4080: train loss 2.8770, val loss 3.0194
# step 4090: train loss 2.8714, val loss 2.8700
# step 4100: train loss 3.0218, val loss 2.8532
# step 4110: train loss 2.9431, val loss 3.0198
# step 4120: train loss 2.8781, val loss 2.9823
# step 4130: train loss 2.9309, val loss 2.9675
# step 4140: train loss 2.9604, val loss 2.9717
# step 4150: train loss 2.9482, val loss 2.9470
# step 4160: train loss 2.8957, val loss 2.9464
# step 4170: train loss 3.0407, val loss 3.0177
# step 4180: train loss 2.9590, val loss 2.9530
# step 4190: train loss 2.9922, val loss 2.9203
# step 4200: train loss 3.0157, val loss 2.9946
# step 4210: train loss 2.9332, val loss 2.9661
# step 4220: train loss 2.8702, val loss 2.9895
# step 4230: train loss 2.9346, val loss 2.9656
# step 4240: train loss 2.9627, val loss 2.9281
# step 4250: train loss 2.9021, val loss 2.9582
# step 4260: train loss 2.9822, val loss 3.0073
# step 4270: train loss 2.9266, val loss 3.0090
# step 4280: train loss 2.9671, val loss 2.9668
# step 4290: train loss 2.9477, val loss 2.9287
# step 4300: train loss 2.9029, val loss 2.9461
# step 4310: train loss 2.9573, val loss 2.9373
# step 4320: train loss 2.8625, val loss 2.9221
# step 4330: train loss 2.8604, val loss 2.9281
# step 4340: train loss 2.8662, val loss 2.9976
# step 4350: train loss 2.9549, val loss 3.0066
# step 4360: train loss 2.9009, val loss 2.9489
# step 4370: train loss 2.8921, val loss 2.9765
# step 4380: train loss 2.8613, val loss 2.9976
# step 4390: train loss 2.9043, val loss 2.9001
# step 4400: train loss 2.8910, val loss 2.9392
# step 4410: train loss 2.9212, val loss 2.8767
# step 4420: train loss 2.8855, val loss 2.9547
# step 4430: train loss 3.0159, val loss 2.9954
# step 4440: train loss 2.9278, val loss 2.9275
# step 4450: train loss 2.8524, val loss 2.8685
# step 4460: train loss 2.8532, val loss 2.9519
# step 4470: train loss 2.8428, val loss 2.8902
# step 4480: train loss 2.9279, val loss 2.9457
# step 4490: train loss 2.8850, val loss 2.8617
# step 4500: train loss 2.8209, val loss 2.9775
# step 4510: train loss 2.7921, val loss 2.8476
# step 4520: train loss 2.8993, val loss 2.9139
# step 4530: train loss 2.8545, val loss 2.9151
# step 4540: train loss 2.9300, val loss 2.8292
# step 4550: train loss 2.8674, val loss 2.8431
# step 4560: train loss 2.8926, val loss 2.9061
# step 4570: train loss 2.9177, val loss 3.0077
# step 4580: train loss 2.8470, val loss 3.0751
# step 4590: train loss 2.8634, val loss 2.9675
# step 4600: train loss 2.8964, val loss 2.8781
# step 4610: train loss 2.9317, val loss 2.9228
# step 4620: train loss 2.8376, val loss 2.8621
# step 4630: train loss 2.8974, val loss 2.8926
# step 4640: train loss 2.9167, val loss 2.9176
# step 4650: train loss 2.8685, val loss 2.9180
# step 4660: train loss 2.8102, val loss 2.8523
# step 4670: train loss 2.8937, val loss 2.8698
# step 4680: train loss 2.8419, val loss 2.8662
# step 4690: train loss 2.8857, val loss 2.8183
# step 4700: train loss 2.8168, val loss 2.8894
# step 4710: train loss 2.9236, val loss 2.9388
# step 4720: train loss 2.8576, val loss 2.8129
# step 4730: train loss 2.7861, val loss 2.9760
# step 4740: train loss 2.7763, val loss 2.8543
# step 4750: train loss 2.8854, val loss 2.8599
# step 4760: train loss 2.8386, val loss 2.8866
# step 4770: train loss 2.8548, val loss 2.9046
# step 4780: train loss 2.8573, val loss 2.9422
# step 4790: train loss 2.7856, val loss 3.0543
# step 4800: train loss 2.8195, val loss 2.8366
# step 4810: train loss 2.8247, val loss 2.9883
# step 4820: train loss 2.8461, val loss 2.9923
# step 4830: train loss 2.8511, val loss 2.8730
# step 4840: train loss 2.8323, val loss 2.7979
# step 4850: train loss 2.8586, val loss 2.8771
# step 4860: train loss 2.8844, val loss 2.9279
# step 4870: train loss 2.8654, val loss 2.7360
# step 4880: train loss 2.8227, val loss 2.8807
# step 4890: train loss 2.7815, val loss 2.8623
# step 4900: train loss 2.7842, val loss 2.8047
# step 4910: train loss 2.7932, val loss 2.8813
# step 4920: train loss 2.7909, val loss 2.8160
# step 4930: train loss 2.8035, val loss 2.8810
# step 4940: train loss 2.8320, val loss 2.9603
# step 4950: train loss 2.7512, val loss 2.8192
# step 4960: train loss 2.7540, val loss 2.8779
# step 4970: train loss 2.7579, val loss 2.8584
# step 4980: train loss 2.8245, val loss 2.7391
# step 4990: train loss 2.8019, val loss 2.8559
# step 5000: train loss 2.8692, val loss 2.8623
# step 5010: train loss 2.8656, val loss 2.9326
# step 5020: train loss 2.7753, val loss 2.8669
# step 5030: train loss 2.7951, val loss 2.7863
# step 5040: train loss 2.8010, val loss 2.8398
# step 5050: train loss 2.8092, val loss 2.7415
# step 5060: train loss 2.7935, val loss 2.7477
# step 5070: train loss 2.8106, val loss 2.7216
# step 5080: train loss 2.8276, val loss 2.9928
# step 5090: train loss 2.7868, val loss 2.8311
# step 5100: train loss 2.8646, val loss 2.9020
# step 5110: train loss 2.7484, val loss 2.7424
# step 5120: train loss 2.8219, val loss 2.8984
# step 5130: train loss 2.7313, val loss 2.7792
# step 5140: train loss 2.8542, val loss 2.8747
# step 5150: train loss 2.7371, val loss 2.8192
# step 5160: train loss 2.7813, val loss 2.8361
# step 5170: train loss 2.6872, val loss 2.7459
# step 5180: train loss 2.8262, val loss 2.8558
# step 5190: train loss 2.7450, val loss 2.8062
# step 5200: train loss 2.7954, val loss 2.9106
# step 5210: train loss 2.7657, val loss 2.8253
# step 5220: train loss 2.8443, val loss 2.8541
# step 5230: train loss 2.7886, val loss 2.7497
# step 5240: train loss 2.7570, val loss 2.8563
# step 5250: train loss 2.7005, val loss 2.8274
# step 5260: train loss 2.7452, val loss 2.8221
# step 5270: train loss 2.7735, val loss 2.8837
# step 5280: train loss 2.7079, val loss 2.7337
# step 5290: train loss 2.7595, val loss 2.8107
# step 5300: train loss 2.7453, val loss 2.7907
# step 5310: train loss 2.7729, val loss 2.8285
# step 5320: train loss 2.7431, val loss 2.8403
# step 5330: train loss 2.7553, val loss 2.8567
# step 5340: train loss 2.7273, val loss 2.8016
# step 5350: train loss 2.7272, val loss 2.8302
# step 5360: train loss 2.7486, val loss 2.7069
# step 5370: train loss 2.7864, val loss 2.8621
# step 5380: train loss 2.7399, val loss 2.8094
# step 5390: train loss 2.6731, val loss 2.7165
# step 5400: train loss 2.7482, val loss 2.6672
# step 5410: train loss 2.6724, val loss 2.8401
# step 5420: train loss 2.6933, val loss 2.8892
# step 5430: train loss 2.8006, val loss 2.7874
# step 5440: train loss 2.6719, val loss 2.8194
# step 5450: train loss 2.7076, val loss 2.8927
# step 5460: train loss 2.7276, val loss 2.8918
# step 5470: train loss 2.7823, val loss 2.7825
# step 5480: train loss 2.7472, val loss 2.8077
# step 5490: train loss 2.6924, val loss 2.8647
# step 5500: train loss 2.7702, val loss 2.7867
# step 5510: train loss 2.7219, val loss 2.7610
# step 5520: train loss 2.7532, val loss 2.8427
# step 5530: train loss 2.7216, val loss 2.9210
# step 5540: train loss 2.7024, val loss 2.8934
# step 5550: train loss 2.7790, val loss 2.6504
# step 5560: train loss 2.7689, val loss 2.9656
# step 5570: train loss 2.6907, val loss 2.6679
# step 5580: train loss 2.6665, val loss 2.8702
# step 5590: train loss 2.7970, val loss 2.7243
# step 5600: train loss 2.7340, val loss 2.7780
# step 5610: train loss 2.7872, val loss 2.9414
# step 5620: train loss 2.7573, val loss 2.7746
# step 5630: train loss 2.6587, val loss 2.7739
# step 5640: train loss 2.7075, val loss 2.6647
# step 5650: train loss 2.7302, val loss 2.7760
# step 5660: train loss 2.8079, val loss 2.7594
# step 5670: train loss 2.7191, val loss 2.7704
# step 5680: train loss 2.7920, val loss 2.6476
# step 5690: train loss 2.6936, val loss 2.7554
# step 5700: train loss 2.7024, val loss 2.7983
# step 5710: train loss 2.6916, val loss 2.7432
# step 5720: train loss 2.7254, val loss 2.7226
# step 5730: train loss 2.7387, val loss 2.8144
# step 5740: train loss 2.6770, val loss 2.7551
# step 5750: train loss 2.7516, val loss 2.6967
# step 5760: train loss 2.6790, val loss 2.7858
# step 5770: train loss 2.7216, val loss 2.7146
# step 5780: train loss 2.8145, val loss 2.7789
# step 5790: train loss 2.6829, val loss 2.6909
# step 5800: train loss 2.7248, val loss 2.8662
# step 5810: train loss 2.7002, val loss 2.7794
# step 5820: train loss 2.7661, val loss 2.7269
# step 5830: train loss 2.7568, val loss 2.6848
# step 5840: train loss 2.6829, val loss 2.8023
# step 5850: train loss 2.6825, val loss 2.7442
# step 5860: train loss 2.6938, val loss 2.7334
# step 5870: train loss 2.6245, val loss 2.7383
# step 5880: train loss 2.6768, val loss 2.7843
# step 5890: train loss 2.6899, val loss 2.6554
# step 5900: train loss 2.7332, val loss 2.7149
# step 5910: train loss 2.7796, val loss 2.7204
# step 5920: train loss 2.7957, val loss 2.7540
# step 5930: train loss 2.6180, val loss 2.8427
# step 5940: train loss 2.7731, val loss 2.7275
# step 5950: train loss 2.6883, val loss 2.8661
# step 5960: train loss 2.6680, val loss 2.7276
# step 5970: train loss 2.6792, val loss 2.7579
# step 5980: train loss 2.7407, val loss 2.7631
# step 5990: train loss 2.7135, val loss 2.7270
# step 6000: train loss 2.6584, val loss 2.8111
# step 6010: train loss 2.6920, val loss 2.6702
# step 6020: train loss 2.6692, val loss 2.6885
# step 6030: train loss 2.7869, val loss 2.7356
# step 6040: train loss 2.5978, val loss 2.7259
# step 6050: train loss 2.6247, val loss 2.7604
# step 6060: train loss 2.6412, val loss 2.7375
# step 6070: train loss 2.7221, val loss 2.6014
# step 6080: train loss 2.7359, val loss 2.7266
# step 6090: train loss 2.7038, val loss 2.7671
# step 6100: train loss 2.6700, val loss 2.8012
# step 6110: train loss 2.6281, val loss 2.7617
# step 6120: train loss 2.8338, val loss 2.8655
# step 6130: train loss 2.6290, val loss 2.7584
# step 6140: train loss 2.6389, val loss 2.7532
# step 6150: train loss 2.6180, val loss 2.7161
# step 6160: train loss 2.6842, val loss 2.7162
# step 6170: train loss 2.6656, val loss 2.7883
# step 6180: train loss 2.6641, val loss 2.8183
# step 6190: train loss 2.6010, val loss 2.7818
# step 6200: train loss 2.6924, val loss 2.7036
# step 6210: train loss 2.7141, val loss 2.6845
# step 6220: train loss 2.7257, val loss 2.6844
# step 6230: train loss 2.6644, val loss 2.7450
# step 6240: train loss 2.6346, val loss 2.6196
# step 6250: train loss 2.6671, val loss 2.7239
# step 6260: train loss 2.7224, val loss 2.6896
# step 6270: train loss 2.6921, val loss 2.8392
# step 6280: train loss 2.5990, val loss 2.7636
# step 6290: train loss 2.7309, val loss 2.6632
# step 6300: train loss 2.5751, val loss 2.6592
# step 6310: train loss 2.6268, val loss 2.8192
# step 6320: train loss 2.6364, val loss 2.7028
# step 6330: train loss 2.7035, val loss 2.6761
# step 6340: train loss 2.6993, val loss 2.7125
# step 6350: train loss 2.6684, val loss 2.6787
# step 6360: train loss 2.7428, val loss 2.7338
# step 6370: train loss 2.6550, val loss 2.6964
# step 6380: train loss 2.6587, val loss 2.7928
# step 6390: train loss 2.6867, val loss 2.7414
# step 6400: train loss 2.7058, val loss 2.8092
# step 6410: train loss 2.6157, val loss 2.6790
# step 6420: train loss 2.6978, val loss 2.7058
# step 6430: train loss 2.6983, val loss 2.7253
# step 6440: train loss 2.6523, val loss 2.6809
# step 6450: train loss 2.5924, val loss 2.7062
# step 6460: train loss 2.7594, val loss 2.6967
# step 6470: train loss 2.6960, val loss 2.7523
# step 6480: train loss 2.7429, val loss 2.6402
# step 6490: train loss 2.6387, val loss 2.6769
# step 6500: train loss 2.6874, val loss 2.6943
# step 6510: train loss 2.6223, val loss 2.7055
# step 6520: train loss 2.7374, val loss 2.7524
# step 6530: train loss 2.6064, val loss 2.6692
# step 6540: train loss 2.6501, val loss 2.6515
# step 6550: train loss 2.6652, val loss 2.8026
# step 6560: train loss 2.7012, val loss 2.6865
# step 6570: train loss 2.6801, val loss 2.6230
# step 6580: train loss 2.7042, val loss 2.7968
# step 6590: train loss 2.6261, val loss 2.7128
# step 6600: train loss 2.6599, val loss 2.6799
# step 6610: train loss 2.5864, val loss 2.7716
# step 6620: train loss 2.6359, val loss 2.7214
# step 6630: train loss 2.5840, val loss 2.7744
# step 6640: train loss 2.6387, val loss 2.7623
# step 6650: train loss 2.6451, val loss 2.6928
# step 6660: train loss 2.6266, val loss 2.6343
# step 6670: train loss 2.6534, val loss 2.7562
# step 6680: train loss 2.6376, val loss 2.6704
# step 6690: train loss 2.6908, val loss 2.8737
# step 6700: train loss 2.5507, val loss 2.6794
# step 6710: train loss 2.6599, val loss 2.5742
# step 6720: train loss 2.5942, val loss 2.5935
# step 6730: train loss 2.6745, val loss 2.6810
# step 6740: train loss 2.5977, val loss 2.8495
# step 6750: train loss 2.6679, val loss 2.8070
# step 6760: train loss 2.6643, val loss 2.6972
# step 6770: train loss 2.6498, val loss 2.6658
# step 6780: train loss 2.6379, val loss 2.7725
# step 6790: train loss 2.6647, val loss 2.6645
# step 6800: train loss 2.6958, val loss 2.7689
# step 6810: train loss 2.5827, val loss 2.6172
# step 6820: train loss 2.5277, val loss 2.6396
# step 6830: train loss 2.7056, val loss 2.7523
# step 6840: train loss 2.6167, val loss 2.6262
# step 6850: train loss 2.5874, val loss 2.7951
# step 6860: train loss 2.5626, val loss 2.7704
# step 6870: train loss 2.6519, val loss 2.6152
# step 6880: train loss 2.6686, val loss 2.6042
# step 6890: train loss 2.5958, val loss 2.7967
# step 6900: train loss 2.6194, val loss 2.6792
# step 6910: train loss 2.6089, val loss 2.6047
# step 6920: train loss 2.5837, val loss 2.6707
# step 6930: train loss 2.6043, val loss 2.5986
# step 6940: train loss 2.5457, val loss 2.6696
# step 6950: train loss 2.5972, val loss 2.5683
# step 6960: train loss 2.5887, val loss 2.7427
# step 6970: train loss 2.6086, val loss 2.7077
# step 6980: train loss 2.5962, val loss 2.6259
# step 6990: train loss 2.6390, val loss 2.7137
# step 7000: train loss 2.5079, val loss 2.6989
# step 7010: train loss 2.5987, val loss 2.5899
# step 7020: train loss 2.6011, val loss 2.7526
# step 7030: train loss 2.6323, val loss 2.5498
# step 7040: train loss 2.6289, val loss 2.8105
# step 7050: train loss 2.5856, val loss 2.6919
# step 7060: train loss 2.6443, val loss 2.6865
# step 7070: train loss 2.6006, val loss 2.7653
# step 7080: train loss 2.6022, val loss 2.6560
# step 7090: train loss 2.6478, val loss 2.8401
# step 7100: train loss 2.6722, val loss 2.7995
# step 7110: train loss 2.6425, val loss 2.6576
# step 7120: train loss 2.6347, val loss 2.7153
# step 7130: train loss 2.6039, val loss 2.5419
# step 7140: train loss 2.5797, val loss 2.6897
# step 7150: train loss 2.5891, val loss 2.7764
# step 7160: train loss 2.5497, val loss 2.6325
# step 7170: train loss 2.5584, val loss 2.6679
# step 7180: train loss 2.5895, val loss 2.7228
# step 7190: train loss 2.5405, val loss 2.6124
# step 7200: train loss 2.6182, val loss 2.6561
# step 7210: train loss 2.6124, val loss 2.6681
# step 7220: train loss 2.5894, val loss 2.6153
# step 7230: train loss 2.5676, val loss 2.6709
# step 7240: train loss 2.6295, val loss 2.6189
# step 7250: train loss 2.4898, val loss 2.6282
# step 7260: train loss 2.6053, val loss 2.7337
# step 7270: train loss 2.5610, val loss 2.7107
# step 7280: train loss 2.5770, val loss 2.5994
# step 7290: train loss 2.6534, val loss 2.5836
# step 7300: train loss 2.6541, val loss 2.6385
# step 7310: train loss 2.6081, val loss 2.6672
# step 7320: train loss 2.6140, val loss 2.6238
# step 7330: train loss 2.6259, val loss 2.5810
# step 7340: train loss 2.6107, val loss 2.6722
# step 7350: train loss 2.5373, val loss 2.5395
# step 7360: train loss 2.6544, val loss 2.6552
# step 7370: train loss 2.5848, val loss 2.6293
# step 7380: train loss 2.6102, val loss 2.5877
# step 7390: train loss 2.4937, val loss 2.7069
# step 7400: train loss 2.5690, val loss 2.6374
# step 7410: train loss 2.6391, val loss 2.6178
# step 7420: train loss 2.6062, val loss 2.6852
# step 7430: train loss 2.6197, val loss 2.7394
# step 7440: train loss 2.5039, val loss 2.6387
# step 7450: train loss 2.6111, val loss 2.5324
# step 7460: train loss 2.4675, val loss 2.6686
# step 7470: train loss 2.4894, val loss 2.6446
# step 7480: train loss 2.6061, val loss 2.6504
# step 7490: train loss 2.5379, val loss 2.6121
# step 7500: train loss 2.4933, val loss 2.6409
# step 7510: train loss 2.5587, val loss 2.6539
# step 7520: train loss 2.5298, val loss 2.6609
# step 7530: train loss 2.5263, val loss 2.6223
# step 7540: train loss 2.6197, val loss 2.6329
# step 7550: train loss 2.6263, val loss 2.6151
# step 7560: train loss 2.5901, val loss 2.6448
# step 7570: train loss 2.5435, val loss 2.7382
# step 7580: train loss 2.6034, val loss 2.6692
# step 7590: train loss 2.5825, val loss 2.6184
# step 7600: train loss 2.6110, val loss 2.6090
# step 7610: train loss 2.5730, val loss 2.7868
# step 7620: train loss 2.5977, val loss 2.6137
# step 7630: train loss 2.5798, val loss 2.6944
# step 7640: train loss 2.6017, val loss 2.6295
# step 7650: train loss 2.5762, val loss 2.5989
# step 7660: train loss 2.6492, val loss 2.7510
# step 7670: train loss 2.5533, val loss 2.6012
# step 7680: train loss 2.6336, val loss 2.6688
# step 7690: train loss 2.5220, val loss 2.5656
# step 7700: train loss 2.5803, val loss 2.6296
# step 7710: train loss 2.5011, val loss 2.6574
# step 7720: train loss 2.5347, val loss 2.6404
# step 7730: train loss 2.5149, val loss 2.6005
# step 7740: train loss 2.5573, val loss 2.6701
# step 7750: train loss 2.5768, val loss 2.6278
# step 7760: train loss 2.5410, val loss 2.6053
# step 7770: train loss 2.6173, val loss 2.5899
# step 7780: train loss 2.5221, val loss 2.5954
# step 7790: train loss 2.5288, val loss 2.7070
# step 7800: train loss 2.5864, val loss 2.6007
# step 7810: train loss 2.5534, val loss 2.5696
# step 7820: train loss 2.5996, val loss 2.6535
# step 7830: train loss 2.5390, val loss 2.6990
# step 7840: train loss 2.5855, val loss 2.7601
# step 7850: train loss 2.6301, val loss 2.5811
# step 7860: train loss 2.5648, val loss 2.7176
# step 7870: train loss 2.6390, val loss 2.6855
# step 7880: train loss 2.6045, val loss 2.7195
# step 7890: train loss 2.5445, val loss 2.5904
# step 7900: train loss 2.5556, val loss 2.5797
# step 7910: train loss 2.5577, val loss 2.5127
# step 7920: train loss 2.5593, val loss 2.6345
# step 7930: train loss 2.5977, val loss 2.5887
# step 7940: train loss 2.6104, val loss 2.6811
# step 7950: train loss 2.5376, val loss 2.5638
# step 7960: train loss 2.6377, val loss 2.7062
# step 7970: train loss 2.6628, val loss 2.5314
# step 7980: train loss 2.5961, val loss 2.6930
# step 7990: train loss 2.5493, val loss 2.6481
# step 8000: train loss 2.4761, val loss 2.6452
# step 8010: train loss 2.6235, val loss 2.7180
# step 8020: train loss 2.6001, val loss 2.6794
# step 8030: train loss 2.5191, val loss 2.5645
# step 8040: train loss 2.6411, val loss 2.5678
# step 8050: train loss 2.5741, val loss 2.6259
# step 8060: train loss 2.5319, val loss 2.5603
# step 8070: train loss 2.5426, val loss 2.5831
# step 8080: train loss 2.5680, val loss 2.6598
# step 8090: train loss 2.6059, val loss 2.6763
# step 8100: train loss 2.5109, val loss 2.6317
# step 8110: train loss 2.6371, val loss 2.6460
# step 8120: train loss 2.5450, val loss 2.7140
# step 8130: train loss 2.5516, val loss 2.5965
# step 8140: train loss 2.4849, val loss 2.6047
# step 8150: train loss 2.5666, val loss 2.6854
# step 8160: train loss 2.5514, val loss 2.5774
# step 8170: train loss 2.5054, val loss 2.5003
# step 8180: train loss 2.5740, val loss 2.5768
# step 8190: train loss 2.5552, val loss 2.6524
# step 8200: train loss 2.4814, val loss 2.5462
# step 8210: train loss 2.5719, val loss 2.5769
# step 8220: train loss 2.5768, val loss 2.5714
# step 8230: train loss 2.5661, val loss 2.6136
# step 8240: train loss 2.5145, val loss 2.4872
# step 8250: train loss 2.5045, val loss 2.6900
# step 8260: train loss 2.5499, val loss 2.7004
# step 8270: train loss 2.5695, val loss 2.5905
# step 8280: train loss 2.5036, val loss 2.6636
# step 8290: train loss 2.5653, val loss 2.6614
# step 8300: train loss 2.5395, val loss 2.5611
# step 8310: train loss 2.5638, val loss 2.5541
# step 8320: train loss 2.5011, val loss 2.6093
# step 8330: train loss 2.5512, val loss 2.5871
# step 8340: train loss 2.5349, val loss 2.5943
# step 8350: train loss 2.5299, val loss 2.5908
# step 8360: train loss 2.5372, val loss 2.6437
# step 8370: train loss 2.5262, val loss 2.5867
# step 8380: train loss 2.6022, val loss 2.5513
# step 8390: train loss 2.5725, val loss 2.5741
# step 8400: train loss 2.5496, val loss 2.6069
# step 8410: train loss 2.5443, val loss 2.6327
# step 8420: train loss 2.4621, val loss 2.5487
# step 8430: train loss 2.6000, val loss 2.5775
# step 8440: train loss 2.4469, val loss 2.6391
# step 8450: train loss 2.5055, val loss 2.4987
# step 8460: train loss 2.5113, val loss 2.5298
# step 8470: train loss 2.4904, val loss 2.5994
# step 8480: train loss 2.5155, val loss 2.6649
# step 8490: train loss 2.4815, val loss 2.5295
# step 8500: train loss 2.5731, val loss 2.5916
# step 8510: train loss 2.6208, val loss 2.5815
# step 8520: train loss 2.5346, val loss 2.5939
# step 8530: train loss 2.5169, val loss 2.6376
# step 8540: train loss 2.5074, val loss 2.5351
# step 8550: train loss 2.5959, val loss 2.5057
# step 8560: train loss 2.5820, val loss 2.6453
# step 8570: train loss 2.4977, val loss 2.5526
# step 8580: train loss 2.5991, val loss 2.5953
# step 8590: train loss 2.5470, val loss 2.6285
# step 8600: train loss 2.5586, val loss 2.6528
# step 8610: train loss 2.5988, val loss 2.5808
# step 8620: train loss 2.4591, val loss 2.6420
# step 8630: train loss 2.4784, val loss 2.5463
# step 8640: train loss 2.5423, val loss 2.5916
# step 8650: train loss 2.5627, val loss 2.7201
# step 8660: train loss 2.5231, val loss 2.7009
# step 8670: train loss 2.5331, val loss 2.5543
# step 8680: train loss 2.5483, val loss 2.5255
# step 8690: train loss 2.5144, val loss 2.4957
# step 8700: train loss 2.5480, val loss 2.5871
# step 8710: train loss 2.5510, val loss 2.4509
# step 8720: train loss 2.5564, val loss 2.5342
# step 8730: train loss 2.4832, val loss 2.5258
# step 8740: train loss 2.5930, val loss 2.5680
# step 8750: train loss 2.5087, val loss 2.5677
# step 8760: train loss 2.5448, val loss 2.5776
# step 8770: train loss 2.5054, val loss 2.4907
# step 8780: train loss 2.5225, val loss 2.5577
# step 8790: train loss 2.4725, val loss 2.6268
# step 8800: train loss 2.5791, val loss 2.5541
# step 8810: train loss 2.4623, val loss 2.4998
# step 8820: train loss 2.6089, val loss 2.5028
# step 8830: train loss 2.4996, val loss 2.6397
# step 8840: train loss 2.4480, val loss 2.5591
# step 8850: train loss 2.5764, val loss 2.6147
# step 8860: train loss 2.4903, val loss 2.5992
# step 8870: train loss 2.5251, val loss 2.6504
# step 8880: train loss 2.5921, val loss 2.6120
# step 8890: train loss 2.5795, val loss 2.4751
# step 8900: train loss 2.5282, val loss 2.5628
# step 8910: train loss 2.5081, val loss 2.6063
# step 8920: train loss 2.4860, val loss 2.5687
# step 8930: train loss 2.4804, val loss 2.5423
# step 8940: train loss 2.4743, val loss 2.5740
# step 8950: train loss 2.5322, val loss 2.5336
# step 8960: train loss 2.5537, val loss 2.5997
# step 8970: train loss 2.3975, val loss 2.5776
# step 8980: train loss 2.5234, val loss 2.6502
# step 8990: train loss 2.4667, val loss 2.5507
# step 9000: train loss 2.6406, val loss 2.5054
# step 9010: train loss 2.5709, val loss 2.5318
# step 9020: train loss 2.4594, val loss 2.6923
# step 9030: train loss 2.5379, val loss 2.6687
# step 9040: train loss 2.5377, val loss 2.5208
# step 9050: train loss 2.4712, val loss 2.5459
# step 9060: train loss 2.5112, val loss 2.7071
# step 9070: train loss 2.4948, val loss 2.5167
# step 9080: train loss 2.5047, val loss 2.5078
# step 9090: train loss 2.5844, val loss 2.5738
# step 9100: train loss 2.5055, val loss 2.5385
# step 9110: train loss 2.5068, val loss 2.5372
# step 9120: train loss 2.5194, val loss 2.6254
# step 9130: train loss 2.5841, val loss 2.6549
# step 9140: train loss 2.4643, val loss 2.5958
# step 9150: train loss 2.4973, val loss 2.5509
# step 9160: train loss 2.5460, val loss 2.5686
# step 9170: train loss 2.6883, val loss 2.5138
# step 9180: train loss 2.5495, val loss 2.5235
# step 9190: train loss 2.5381, val loss 2.6229
# step 9200: train loss 2.4774, val loss 2.5735
# step 9210: train loss 2.5076, val loss 2.5117
# step 9220: train loss 2.4932, val loss 2.4336
# step 9230: train loss 2.4536, val loss 2.5992
# step 9240: train loss 2.4762, val loss 2.5856
# step 9250: train loss 2.4736, val loss 2.5636
# step 9260: train loss 2.4899, val loss 2.6390
# step 9270: train loss 2.4034, val loss 2.5552
# step 9280: train loss 2.4885, val loss 2.5579
# step 9290: train loss 2.5250, val loss 2.4980
# step 9300: train loss 2.5186, val loss 2.6166
# step 9310: train loss 2.4922, val loss 2.5456
# step 9320: train loss 2.5291, val loss 2.5498
# step 9330: train loss 2.5307, val loss 2.6280
# step 9340: train loss 2.5168, val loss 2.6002
# step 9350: train loss 2.5061, val loss 2.4760
# step 9360: train loss 2.4057, val loss 2.6539
# step 9370: train loss 2.5209, val loss 2.5564
# step 9380: train loss 2.5327, val loss 2.5221
# step 9390: train loss 2.6109, val loss 2.5387
# step 9400: train loss 2.4761, val loss 2.6265
# step 9410: train loss 2.4967, val loss 2.5796
# step 9420: train loss 2.4777, val loss 2.4497
# step 9430: train loss 2.4771, val loss 2.5652
# step 9440: train loss 2.5006, val loss 2.5760
# step 9450: train loss 2.5303, val loss 2.5458
# step 9460: train loss 2.5513, val loss 2.6166
# step 9470: train loss 2.5431, val loss 2.6633
# step 9480: train loss 2.5873, val loss 2.4640
# step 9490: train loss 2.4958, val loss 2.5694
# step 9500: train loss 2.4631, val loss 2.5353
# step 9510: train loss 2.5036, val loss 2.5242
# step 9520: train loss 2.4498, val loss 2.5273
# step 9530: train loss 2.4981, val loss 2.5708
# step 9540: train loss 2.4763, val loss 2.6729
# step 9550: train loss 2.5456, val loss 2.5382
# step 9560: train loss 2.5119, val loss 2.5458
# step 9570: train loss 2.4978, val loss 2.5789
# step 9580: train loss 2.5752, val loss 2.5992
# step 9590: train loss 2.5096, val loss 2.6112
# step 9600: train loss 2.4363, val loss 2.6319
# step 9610: train loss 2.5822, val loss 2.5428
# step 9620: train loss 2.5558, val loss 2.6267
# step 9630: train loss 2.5540, val loss 2.6207
# step 9640: train loss 2.5418, val loss 2.4445
# step 9650: train loss 2.5942, val loss 2.4539
# step 9660: train loss 2.5967, val loss 2.5694
# step 9670: train loss 2.5192, val loss 2.4988
# step 9680: train loss 2.4965, val loss 2.6279
# step 9690: train loss 2.5290, val loss 2.5578
# step 9700: train loss 2.4965, val loss 2.4828
# step 9710: train loss 2.4156, val loss 2.5148
# step 9720: train loss 2.4682, val loss 2.6617
# step 9730: train loss 2.4255, val loss 2.5134
# step 9740: train loss 2.4829, val loss 2.5391
# step 9750: train loss 2.5493, val loss 2.5714
# step 9760: train loss 2.3361, val loss 2.5149
# step 9770: train loss 2.4030, val loss 2.5318
# step 9780: train loss 2.4454, val loss 2.4758
# step 9790: train loss 2.4430, val loss 2.4917
# step 9800: train loss 2.5679, val loss 2.5352
# step 9810: train loss 2.3685, val loss 2.5928
# step 9820: train loss 2.5874, val loss 2.4554
# step 9830: train loss 2.5002, val loss 2.4346
# step 9840: train loss 2.4725, val loss 2.7016
# step 9850: train loss 2.4676, val loss 2.6171
# step 9860: train loss 2.4786, val loss 2.5850
# step 9870: train loss 2.4728, val loss 2.4330
# step 9880: train loss 2.4896, val loss 2.4901
# step 9890: train loss 2.4089, val loss 2.7205
# step 9900: train loss 2.5157, val loss 2.5172
# step 9910: train loss 2.4966, val loss 2.6248
# step 9920: train loss 2.5822, val loss 2.5768
# step 9930: train loss 2.4959, val loss 2.5282
# step 9940: train loss 2.4215, val loss 2.5563
# step 9950: train loss 2.5394, val loss 2.4683
# step 9960: train loss 2.4801, val loss 2.5768
# step 9970: train loss 2.4943, val loss 2.5653
# step 9980: train loss 2.4759, val loss 2.5340
# step 9990: train loss 2.4762, val loss 2.5001

# %%
idx = torch.ones((1,1), dtype=torch.long, device=device)*3
print (decode(m.generate(idx, max_new_tokens=100)[0].tolist()))
# Out:
# CH7rêts t;
#
# L'uxchêpêttrisas tou'E:Jui:'êteséaur,
# Pnt fc9yolpa,
# Ivex dre  ples;
# L6,
#
# A it mère llire

# %% [markdown]
# The training helps decrease the loss. The model gets better and better as we increased the number of maximum iterations.
#
# #### For `max_iter = 100`:
# - The text is almost entirely random.
# - The model hasn’t learned much .
#
# #### For `max_iter = 1000`:
# - There's a small improvement with some recognizable character combinations emerging, but still this is not satisfactory.
#
# #### For `max_iter = 10000`:
# - The model starts producing fragments of real words and word-like sequences.
# - Some semblance of sentence structure appears, though still many errors and incoherencies persist.

# %% [markdown]
# ## Single Head Attention
#
# Nous allons maintenant implémenter le mécanisme de base de l'attention. Pour chaque couple de mots de la séquence, ce mécanisme combine Q une *query* (l'information recherchée), K une *key* (l'information obtenue) et calcule  V une *value*, un vecteur de résultat.
#
# ![single head attention](images/single_head_attention.png)
#
# ### Masquage
# Cependant, comme nous utilisons le modèle pour générer des séquences, on ne doit pas utiliser les caractères situés après le caractère courant, car ce sont justement ces caractères que l'on cherche à prédire lors de l'apprentissage : *le futur n'est pas utilisé pour prédire (le futur).*
#
# On va donc intégrer une matrice de masquage dans le processus. Cette matrice indique que pour le premier caractère de la séquence, on ne peux utiliser que ce caractère pour prédire (pas de contexte). Pour le second caractère, on peut utiliser le premier caractère et le second. Pour le troisième caractère, on peut utiliser le premier, le second et le troisième et ainsi de suite. Cette matrice est donc une matrice triangulaire inférieure. Cette matrice est normalisée par ligne (les lignes somment à 1).

# %%
T = 8

# first version of the contraints with matrix multiplication
# create a lower triangular matrix
weights0 = torch.tril(torch.ones(T,T))
# normalize each row
weights0 = weights0 / weights0.sum(1, keepdim=True) 
print (weights0)
# Out:
# tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.5000, 0.5000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.3333, 0.3333, 0.3333, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2500, 0.2500, 0.2500, 0.2500, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.0000, 0.0000, 0.0000],
#         [0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.0000, 0.0000],
#         [0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.0000],
#         [0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250]])

# %% [markdown]
# La couche [`softmax`](https://pytorch.org/docs/stable/generated/torch.nn.functional.softmax.html) est une autre manière de réaliser la normalisation :
#
# Question :
# > * Vérifier qu'on obtient bien la même matrice.

# %%
tril = torch.tril(torch.ones(T,T))
weights = torch.tril(torch.ones(T,T))
weights = weights.masked_fill(tril== 0, float('-inf'))
weights = nn.functional.softmax(weights, dim=-1)
print (weights)
# Out:
# tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.5000, 0.5000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.3333, 0.3333, 0.3333, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2500, 0.2500, 0.2500, 0.2500, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.0000, 0.0000, 0.0000],
#         [0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.0000, 0.0000],
#         [0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.0000],
#         [0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250]])

# %% [markdown]
# ### Implémentation
#
# Nous pouvons maintenant implémenter la couche d'attention :
#
# ![attention_formula](images/attention_formula.png)

# %% [markdown]
# Questions :
#
# > * Créer les couches key, query et value comme des couches linéaires de dimension `C` x `head_size`.
# > * Appliquer les couches à `x`.
# > * `weights = query x key` (transposer les deuxième et troisième dimensions de key pour pouvoir faire le produit).
# > * Appliquer le facteur de normalisation.
# > * Appliquer le masque triangulaire et la softmax à `weights`.
# > * Appliquer value à `x`.
# > * Le résultat `out` est la multiplication de `weights` par `value(x)`.

# %%
head_size = 16
B, T, C = 4, 8, 32
x = torch.randn(B, T, C)
## YOUR CODE HERE
# define the Key layer  
key = nn.Linear(C, head_size)
# define the Query layer
query = nn.Linear(C, head_size)
# define the Value layer
value =  nn.Linear(C, head_size)
# apply each layer to the input
k = key(x) # (B, T, head_size)
q = query(x) # (B, T, head_size)
v = value(x) # (B, T, head_size)
# compute the normalize product between Q and K 
weights = torch.matmul(q, k.transpose(1, 2))/math.sqrt(head_size) # (B, T, head_size) @ (B, 16, head_size) -> (B, T, T)
# apply the mask (lower triangular matrix)
mask = torch.tril(torch.ones(T, T))  
mask = mask / mask.sum(1, keepdim=True)
weights = weights.masked_fill(tril== 0, float('-inf'))
# apply the softmax
weights = torch.nn.functional.softmax(weights, dim=-1)
###
out  = weights @ value(x) # (B, T, head_size)

# print the result
weights[0]
out[0]
# Out:
# tensor([[-8.9850e-01,  3.8935e-01, -4.3960e-01, -2.6513e-01,  7.3291e-01,
#          -2.0194e-01, -9.5521e-01, -4.7184e-01,  2.6718e-01, -2.2185e-01,
#           3.8973e-01, -7.5716e-02, -5.1194e-01,  2.5533e-01, -1.8047e-01,
#          -6.1030e-01],
#         [-1.4969e-01,  1.8733e-01, -4.7682e-01,  1.2639e-01,  1.7940e-01,
#           1.9705e-01, -3.6869e-01, -1.9939e-01,  6.1172e-02,  2.5805e-01,
#           2.4590e-02,  2.0028e-01, -6.2002e-01, -2.7608e-01, -2.1533e-01,
#           9.5765e-02],
#         [-1.5237e-01,  8.4667e-02, -3.9044e-01,  4.1155e-02,  9.8322e-02,
#           2.3628e-01, -2.5759e-01, -1.5061e-02,  2.0831e-02,  3.3847e-01,
#          -7.5492e-02,  1.0572e-01, -3.4317e-01,  1.5553e-01, -3.0630e-01,
#          -1.9154e-01],
#         [-4.1019e-01,  1.1664e-01, -3.7570e-01, -7.8630e-02,  8.3774e-02,
#           2.7973e-01, -3.9195e-01,  1.4700e-01, -1.1600e-01,  9.2984e-02,
#           7.4603e-02,  1.5121e-01, -3.0818e-01,  1.2836e-02, -1.7262e-01,
#          -3.0860e-01],
#         [-2.2309e-01,  8.5143e-02, -3.4961e-01, -3.0323e-02,  7.4455e-02,
#           1.9240e-01, -3.3979e-01,  1.6401e-01, -4.4226e-02,  1.3741e-01,
#           8.6978e-04,  2.4281e-01, -2.2956e-01,  1.1157e-01, -2.2246e-01,
#          -2.3175e-01],
#         [-3.5476e-01,  1.8657e-01, -1.6373e-01, -7.7012e-02,  1.4112e-01,
#           1.6663e-01, -4.0098e-01,  1.8296e-01, -4.7647e-02, -5.2066e-02,
#           9.4625e-02,  1.0423e-01, -1.0926e-01,  3.4436e-01, -1.1723e-01,
#          -4.4064e-01],
#         [-2.0614e-01,  2.0621e-01, -1.0858e-01, -4.1656e-02,  2.0946e-01,
#           1.4281e-01, -3.6407e-01,  5.9446e-02, -8.1951e-02,  8.7178e-03,
#           1.0175e-01,  6.2800e-02, -8.1982e-02,  1.7479e-01, -1.2787e-01,
#          -3.4008e-01],
#         [-1.6402e-01,  1.4942e-01, -2.0882e-01, -3.2130e-02,  1.7836e-01,
#           1.2172e-01, -2.6788e-01,  2.7693e-02,  6.1532e-02,  1.9957e-02,
#          -3.0333e-02,  1.6758e-01,  4.3422e-02, -2.5869e-02, -2.8542e-01,
#          -1.9056e-01]], grad_fn=<SelectBackward0>)

# %% [markdown]
# Questions :
#
# > * Copier votre code dans `gpt_single_head.py` : la définition des couches dans le constructeur de la classe `Head` et les calculs dans la fonction `forward`.
# > * Faire un entrainement.
# > * Quelle loss en train et val obtenez vous ? Le texte vous parait-il meilleur ?

# %% [markdown]
# ![alt terminal output](outputs/run_gpt_single.png)

# %% [markdown]
# This text is again slightly better than before, but still not good enough.

# %% [markdown]
# ## Multi-head attention
#
# La *multi-head attention* est simplement le calcul en parallèle de plusieurs *single head attention*. Chacune des single head attention est concaténée pour créer la sortie de la multi-head attention. Dans la figure issue de l'article original, le nombre de *heads* dans le *multi-head* est `h`. Afin d'opérer des combinaisons pondérées sur la sortie de chacune des single head, une couche de calcul linéaire est ajoutée.
#
# ![multi head attention](images/multi_head_attention.png)
#
# Le code ci-dessous crée un module de multi-head attention.
# Questions :
# > * Dans le constructeur, créer une liste contenant `num_heads` module `Head` en utilisant la fonction [ModuleList](https://pytorch.org/docs/stable/generated/torch.nn.ModuleList.html) de pytorch.
# > * Dans la fonction `forward`, appliquer chaque single head à l'input et concaténer le résultat en utilisant la fonction [cat](https://pytorch.org/docs/stable/generated/torch.cat.html) de pytorch.

# %%
from gpt_single_head import Head

# %%
class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        ## YOUR CODE HERE
        ## list of num_heads modules of type Head
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        ###
        
    def forward(self, x):
        ## YOUR CODE HERE
        ## apply each head in self.heads to x and concat the results 
        out = torch.cat([h(x) for h in self.heads], dim=-1)

        return out

# %% [markdown]
# Questions :
# > * Copier le fichier `gpt_single_head.py` en `gpt_multi_head.py`.
# > * Ajouter le module MultiHeadAttention dans `gpt_multi_head.py`.
# > * En tête de fichier, ajouter un paramètre  `n_head = 4`.
# > * Dans le module BigramLanguageModel, remplacer le module Head par un module MultiHeadAttention avec les paramètres `num_heads = n_head` et `head_size = n_embd // n_head` pour garder le même nombre de paramètres.
# > Relancer l'entrainement et noter le nombre de paramètres et les loss obtenues.
#
# <!-- 0.009893 M parameters
# step 4999: train loss 2.1570, val loss 2.1802 -->

# %% [markdown]
# ![alt terminal output](outputs/run_gpt_multiple.png)

# %% [markdown]
# ## Ajout d'une couche de calcul FeedForward
#
#
# Après les couches d'attention qui collectent l'information dans la séquence, une couche de calcul est ajoutée pour combiner toutes les informations de la séquence. Cette couche est un simple Multi-Layer-Perceptron avec une couche cachée et une non linéarité de type [RELU](https://pytorch.org/docs/stable/generated/torch.nn.ReLU.html).
# ![multi feedfoward](images/multi_ff.png)

# %%
class FeedForward(nn.Module):
    """ a simple MLP with RELU """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, n_embd),
            nn.ReLU(),
        )

    def forward(self, x):
        return self.net(x)

# %% [markdown]
# Questions :
# > * Ajouter le module `FeedForward` dans votre fichier `gpt_multi_head.py`.
# > * Ajouter cette couche `FeedForward` après la *multi-head attention*.
# > * Relancer l'entrainement et noter le nombre de paramètres et les loss obtenues.

# %% [markdown]
# <!-- 0.010949 M parameters
# step 4999: train loss 2.1290, val loss 2.1216 -->
#
# ![alt terminal output](outputs/ff_gpt.png)

# %% [markdown]
# ## Empiler les blocs
#
# Le réseau construit jusqu'à présent n'est en fait qu'un bloc du réseau final. Il est maintenant possible d'empiler les blocs de *multi-head attention* pour créer un réseau profond.
#
# ![multi feedfoward](images/multi_bloc.png)
#
#
# Le code suivant crée un bloc :

# %%
class Block(nn.Module):
    """ A single bloc of multi-head attention """

    def __init__(self, n_embd, n_head):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedForward(n_embd)

    def forward(self, x):
        x = self.sa(x)
        x = self.ffwd(x)
        return x

# %% [markdown]
# Questions :
# > * Ajouter le module `Block` dans `gpt_multi_head.py`.
# > * Modifier le code de `BigramLanguageModel` pour ajouter 3 `Block(n_embd, n_head=4)` avec un container [Sequential](https://pytorch.org/docs/stable/generated/torch.nn.Sequential.html) à la place de `MultiHeadAttention`et `FeedForward`.
# > * Relancer l'entrainement et noter le nombre de paramètres et les loss obtenues.
#
# <!-- 0.019205 M parameters
# step 4999: train loss 2.2080, val loss 2.2213 -->

# %% [markdown]
# ![alt terminal output](outputs/gpt_3_block.png)

# %% [markdown]
# ## Amélioration de l'entraînement
#
# Si on veut continuer à augmenter la taille du réseau, il est nécessaire d'utiliser des couches permettant d'améliorer l'entraînement et ses capacités de généralisation (réduire le sur-apprentissage). Ces couches sont :
# - *skip connections* ou *residual connections*
# - les couches de normalisation
# - le dropout.
#
#
# ![multi feedfoward](images/multi_skip_norm.png)
#
#
# Questions :
# > * Dans le module Block, ajouter une skip connection en ajoutant l'input dans chaque connexion :
# ```
#         x = x + self.sa(self.ln1(x))
#         x = x + self.ffwd(self.ln2(x))
# ```
# > * Dans le module Block, ajouter 2 couches de [LayerNorm](https://pytorch.org/docs/stable/generated/torch.nn.LayerNorm.html) de taille `n_embd` avant la couche de `Multi-Head attention` et avant la `FeedForward`.
# > * Après la série de 3 blocs, ajouter une couche de LayerNorm de taille `n_embd`.
# > * Définir une variable `dropout = 0.2` en début de fichier et ajouter une couche de [Dropout](https://pytorch.org/docs/stable/generated/torch.nn.Dropout.html) :
# >    * Après la couche RELU dans FeedForward
# >    * Après la couche de MultiHead dans `MultiHeadAttention`
# >    * Après la softmax dans la single head attention `Head`.
# > * Relancer l'entrainement et noter le nombre de paramètres et les loss obtenues.
#
# <!-- 0.019653 M parameters -->

# %% [markdown]
# ![alt terminal output](outputs/final_gpt.png)

# %% [markdown]
# ## Conclusion
#
# Les principaux éléments de GPT2 sont en place, il faut maintenant faire passer le modèle à l'échelle et l'entraîner sur une base de données beaucoup plus grande. Pour comparaison, les paramètres de [GPT2](https://huggingface.co/transformers/v2.11.0/model_doc/gpt2.html) sont :
#
# * `vocab_size = 50257` : GPT2 modélise des tokens (subwords) alors que nous modélisons des caractères. Pour nous, `vocab_size = 100`.
# * `n_positions = 1024` : la taille maximale du contexte. Pour nous, c'est `block_size = 8`.
# * `n_embd = 768`:  la dimension des embeddings. Pour nous c'est `n_embd = 32`.
# * `n_layer = 12`: le nombre de block. Pour nous c'est 3.
# * `n_head = 12`: le nombre de multi-head attention. Pour nous c'est 4.
#
# Au total, GPT2 est composé de 1,500 millions de paramètres et a été entrainé sur 8M de pages web, soit 40 Gb de texte.
#
#
# ```
# 10.816613 M parameters
# step 0: train loss 4.7847, val loss 4.7701
# step 4999: train loss 0.2683, val loss 2.1161
# time: 31m47.910s
#
# Le pêcheur où l'homme en peu de Carevante
# Sa conter des chosses qu'en ses yoitn!
#
# Ils sont là-hauts parler à leurs ténèbres
# A ceux qu'on rêve aux oiseaux des cheveux,
# Et celus qu'on tourna jamais sous le front;
# Ils se disent tu mêle aux univers.
# J'ai vu Jean vu France, potte; petits contempler,
# Et petié calme au milibre et versait,
# M'éblouissant, emportant, écoute, ingorancessible,
# On meurt s'efferayait.....--Pas cont âme parle en Apparia!
# ```
